# %%
import warnings

from matplotlib import pyplot as plt
import numpy as np

import h5py

# %% [markdown]
# $a = y(\gamma_{i} - 1)$ <br>
# $b = z(\gamma_{e} - 1)$ <br>
# $c = \frac{m_{p}(\gamma_{i} - 1)(\gamma_{e}-1)}{k_{B}(\gamma - 1)}$ <br>
# $Te = \frac{m_{p}u(\gamma_{e}-1)(\gamma_{i}-1)}{k\rho (y(\gamma_{i}-1)+Rz(\gamma_{e}-1))}=c\frac{P_{g}}{\rho(a+bR)}$<br>
# $C[Pg -> Te] = A = \frac{<Te>}{<Pg>}-\frac{2b<Te><Pg>(R_{h} - <R>)}{(<P_{mag}>^{2}+<Pg>^{2})(a+b<R>)}$ <br>
# $C[\rho -> Te] = B = -\frac{<Te>}{<\rho>}$ <br>
# $C[B^{2} -> Te] = C = \frac{b<Te><Pg>}{2\mu_{0}(<P_{mag}>^{2}+<Pg>^{2})(a+b<R>)}$ <br>
# $cov(X, Y) = <XY> - <X><Y>$ <br>
# var(Te) = $(\delta Te)^{2}$ = $A^{2}$var(Pg) + $B^{2}$var($\rho$) + $C^{2}$var(bsq) + 2$AB$cov(Pg, $\rho$) + 2$AC$ cov(Pg, bsq) + 2$BC$ cov($\rho$, bsq)

# %%
# some constants
cl = 29979245800.0 # speed of light in cgs
mp = 1.67262171e-24
kb = 1.3806505e-16
mu = 1.

# %% [markdown]
# <mark>**Summary**</mark>: <br>
# * var(Pg) and var(Te) show similar shape and trends as a function of $\theta$ in inner radius
#     * for middle radius, var(bsq) somehow resembles var(Te) speaking of shape and trend
#     * for outer radius, var(Pg) and var($\rho$) somehow resembles a simplified version of var(Te) speaking of shape and trend
# * C[$\rho$ -> Te] are negative for all cases
#     * abs(C[Pg->Te]) > abs(C[$\rho$->Te]) > abs(C[bsq->Te])
# * The dominant terms in the var(Te) equation are **var(Pg), var($\rho$) and cov(Pg, $\rho$)**

# %% [markdown]
# <h3>MAD</h3> <h5>Rh=1</h5>

# %%
# the var(Te) expected
varTe_file = np.load('ma_rh1_varTe.npy', allow_pickle=True)

# %%
# read in coefficients and other variances to calculate var(Te)
# variances
varPg_file = np.load('ma_varPg.npy', allow_pickle=True)
varRHO_file = np.load('ma_varRHO.npy', allow_pickle=True)
varbsq_file = np.load('ma_varbsq.npy', allow_pickle=True)

# averages
ma_avg_Pg = np.load('ma_avgPg.npy', allow_pickle=True)
ma_avg_RHO = np.load('ma_avgRHO.npy', allow_pickle=True)
ma_avg_bsq = np.load('ma_avgbsq.npy', allow_pickle=True)

ma_avgPgRHO = np.load('ma_avgRHOPg.npy', allow_pickle=True)
ma_avgPgbsq = np.load('ma_avgBsqPg.npy', allow_pickle=True)
ma_avgRHObsq = np.load('ma_avgBsqRHO.npy', allow_pickle=True)

# covariances
ma_covPgRHO = ma_avgPgRHO - ma_avg_Pg * ma_avg_RHO
ma_covPgbsq = ma_avgPgbsq - ma_avg_Pg * ma_avg_bsq
ma_covRHObsq = ma_avgRHObsq - ma_avg_RHO * ma_avg_bsq

# %%
# coefficients
ma_CPg1 = np.load('ma_CPg1.npy')
ma_Crho1 = np.load('ma_Crho1.npy')
ma_Cbsq1 = np.load('ma_Cbsq1.npy')

# %% [markdown]
# **log(variance) + log(Te) VS $\theta$**

# %%
r = 10
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=1)')
plt.show()

# %%
r = 66
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 96
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=1)')
plt.show()

# %% [markdown]
# speaking of the trend (i.e. shape of curve): <br>r=0 to r=40: var(Pg) resembles var(Te) a lot<br> r=60 to r=70, var(bsq) resembles var(Te) <br> for the rest of r, var(Pg) and var(RHO) share similar trends. Though it's hard to tell which one resembles var(Te), overall var(Pg) and var(RHO) look more like the simplified version of var(Te)

# %% [markdown]
# **log(covariance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(ma_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(ma_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 24
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(ma_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(ma_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (MAD, Rh=1)')
plt.show()
# Out:
# /tmp/ipykernel_63443/876965000.py:9: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
# /tmp/ipykernel_63443/876965000.py:11: RuntimeWarning: invalid value encountered in log10
#   axes[2].plot(theta, np.log10(ma_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

# %%
# choose a radius that represents the spherical surface
r = 96
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_file[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(ma_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(ma_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (MAD, Rh=1)')
plt.show()
# Out:
# /tmp/ipykernel_63443/3736335905.py:9: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
# /tmp/ipykernel_63443/3736335905.py:10: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(ma_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')

# %% [markdown]
# Note: there are some radius where covariances are negative (so the log10 curve won't work)
#
# cov(Pg, bsq) resembles var(Te) in inner radius; <br> for around half of the radius, cov(Pg, bsq) and cov(RHO,bsq) look like a simplified version of var(Te)

# %% [markdown]
# **coefficients VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 32
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 63
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 76
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %%
# choose a radius that represents the spherical surface
r = 98
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %%
r = 110
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=1)')
plt.show()

# %% [markdown]
# As r increases (r=5 -> r=32 -> r=63 -> r=76 -> r=98 -> r=110):
#
# C[Pg->Te]: $10^{13}$->$10^{16}$, one peak one trough -> one peak one trough -> two peaks one trough -> two peaks one trough -> two peaks one trough -> two peaks one trough <br>
# C[$\rho$->Te]: $-10^{13}$->$-10^{15}$, two peaks one trough -> one peak one trough -> one peak one trough -> one wide peak -> one wide trough -> one trough <br>
# C[bsq->Te]: $10^{9}$->$10^{12}$, two peaks -> one peak one trough -> one peak one trough -> one peak one trough -> one wide peak -> one peak

# %% [markdown]
# **variances and covariances [Te(calculated) and other quantities] VS $\theta$ with contributions shown**

# %% [markdown]
# var(Te) = $(\delta Te)^{2}$ = $A^{2}$var(Pg) + $B^{2}$var($\rho$) + $C^{2}$var(bsq) + 2$AB$cov(Pg, $\rho$) + 2$AC$ cov(Pg, bsq) + 2$BC$ cov($\rho$, bsq)

# %%
# var(Te) caculated from coefficients and variances
varPg_term = np.square(ma_CPg1)*varPg_file
varRHO_term = np.square(ma_Crho1)*varRHO_file
varbsq_term = np.square(ma_Cbsq1)*varbsq_file
cov_term1 = 2*ma_CPg1*ma_Crho1*ma_covPgRHO
cov_term2 = 2*ma_CPg1*ma_Cbsq1*ma_covPgbsq
cov_term3 = 2*ma_Crho1*ma_Cbsq1*ma_covRHObsq
varTe_coeff = varPg_term + varRHO_term + varbsq_term + cov_term1 + cov_term2 + cov_term3

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)
# cov_term1[r, 0, :], cov_term2[r, 0, :], cov_term3[r, 0, :]
terms = np.vstack([varTe_coeff[r, 0, :], varPg_term[r, 0, :], varRHO_term[r, 0, :], varbsq_term[r, 0, :]])

plt.stackplot(theta, terms, labels=['var(Te)[calculated]', 'A^2 var(Pg)', 'B^2 var(RHO)', 'C^2 var(bsq)'])
plt.xlabel('theta')
plt.ylabel('var terms')
plt.legend()
plt.show()

# %%
r = 126
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.title('Contribution to var(Te) By Term (MAD, Rh=1)')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.show()

# %%
r = 64
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.title('Contribution to var(Te) By Term (MAD, Rh=1)')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.show()

# %%
r = 88
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.title('Contribution to var(Te) By Term (MAD, Rh=1)')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.show()

# %% [markdown]
# bsq terms (variance or covariance) barely have any influence

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (MAD, Rh=1)')
plt.ylim(20, 25)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)
plt.fill_between(theta, np.log10(varTe_file[r, 0, :]), label='var(Te)[expected]', color='orange', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (MAD, Rh=1)')
plt.ylim(20, 25)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()

# %% [markdown]
# Tried a lot of different r, the Pg and $\rho$ terms (**var(Pg), var($\rho$), and cov(Pg, $\rho$)**) are the ones that contribute the most to var(Te) <br> There are some fluctuations but not much <br> The smaller r is, the closer the three quantities shown in the above graph are

# %% [markdown]
# <h5>Rh=160</h5>

# %%
# the var(Te) expected
varTe_rh160 = np.load('ma_rh160_varTe.npy', allow_pickle=True)

# %%
# coefficients for MAD Rh=160
ma_CPg160 = np.load('ma_CPg160.npy')
ma_Crho160 = np.load('ma_Crho160.npy')
ma_Cbsq160 = np.load('ma_Cbsq160.npy')

# %% [markdown]
# **log(variance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=160)')
plt.show()

# %%
r = 22
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=160)')
plt.show()

# %%
r = 64
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=160)')
plt.show()

# %%
r = 96
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_file[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_file[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_file[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (MAD, Rh=160)')
plt.show()

# %% [markdown]
# For inner radius, var(Pg) resembles var(Te); for inner to middle radius, var(bsq) resembles var(Te); for the rest of the radius, it's hard to tell.

# %% [markdown]
# **log(covariance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(ma_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(ma_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(ma_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (MAD, Rh=160)')
plt.show()

# %% [markdown]
# **coefficients VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg160[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho160[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq160[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=160)')
plt.show()

# %%
r = 60
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg160[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho160[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq160[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=160)')
plt.show()

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, ma_CPg160[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, ma_Crho160[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, ma_Cbsq160[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (MAD, Rh=160)')
plt.show()

# %% [markdown]
# As r increases (r=5 -> r = 22 -> r = 36 -> r=48 -> r=60 -> r=72 -> r=84 -> r=96 -> r=108): <br>
# C[Pg->Te]: $10^{13}$->$10^{16}$, two peaks one trough -> two peaks one trough -> two peaks one trough -> two peaks one trough -> two peaks one trough -> two peaks one trough -> one peak one trough -> one peak one trough -> hard to describe <br>
# C[$\rho$->Te]: $-10^{13}$->$-10^{15}$, one peak one trough -> one peak two troughs -> two peaks one trough -> two peaks two troughs -> one peak two troughs -> three peaks two troughs -> two peaks -> two peaks one trough -> two peaks one trough <br>
# C[bsq->Te]: $10^{9}$->$10^{12}$, one peak one trough -> two peaks two troughs -> one peak one trough -> one peak one trough -> one peak one trough -> one peak one trough -> one peak one trough -> one peak one trough -> one peak two troughs <br>

# %% [markdown]
# **variances and covariances [Te(calculated) and other quantities] VS $\theta$ with contributions shown**

# %% [markdown]
# var(Te) = $(\delta Te)^{2}$ = $A^{2}$var(Pg) + $B^{2}$var($\rho$) + $C^{2}$var(bsq) + 2$AB$cov(Pg, $\rho$) + 2$AC$ cov(Pg, bsq) + 2$BC$ cov($\rho$, bsq)

# %%
# var(Te) caculated from coefficients and variances
varPg_term_rh160 = np.square(ma_CPg160)*varPg_file
varRHO_term_rh160 = np.square(ma_Crho160)*varRHO_file
varbsq_term_rh160 = np.square(ma_Cbsq160)*varbsq_file
cov_term1_rh160 = 2*ma_CPg160*ma_Crho160*ma_covPgRHO
cov_term2_rh160 = 2*ma_CPg160*ma_Cbsq160*ma_covPgbsq
cov_term3_rh160 = 2*ma_Crho160*ma_Cbsq160*ma_covRHObsq
varTe_coeff_rh160 = varPg_term_rh160 + varRHO_term_rh160 + varbsq_term_rh160 + cov_term1_rh160 + cov_term2_rh160 + cov_term3_rh160

# %%
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term_rh160[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term_rh160[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term_rh160[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1_rh160[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2_rh160[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3_rh160[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff_rh160[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.title('Contribution to var(Te) By Term (MAD, Rh=160)')
plt.show()

# %%
r = 32
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (MAD, Rh=160)')
plt.ylim(20, 25)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)
plt.fill_between(theta, np.log10(varTe_rh160[r, 0, :]), label='var(Te)[expected]', color='orange', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (MAD, Rh=160)')
plt.ylim(20, 25)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()

# %% [markdown]
# For MAD model, the Pg and $\rho$ terms (**var(Pg), var($\rho$), and cov(Pg, $\rho$)**) are the ones that contribute the most to var(Te) <br> Overall slightly higher fluctuations (especially in the middle radius range) compared with Rh=1 <br> Still the smaller r is, the closer the three quantities listed above are

# %% [markdown]
# ## SANE

# %% [markdown]
# <h5>Rh=1</h5>

# %%
# the var(Te) directly calculated from the equation
varTe_sa = np.load('sa_rh1_varTe.npy', allow_pickle=True)

# %%
# read in coefficients and other variances to calculate var(Te)
# variances
varPg_sa = np.load('sa_varPg.npy', allow_pickle=True)
varRHO_sa = np.load('sa_varRHO.npy', allow_pickle=True)
varbsq_sa = np.load('sa_varbsq.npy', allow_pickle=True)

# averages
sa_avg_Pg = np.load('sa_avgPg.npy', allow_pickle=True).item()['Pg']
sa_avg_RHO = np.load('sa_avgRHO.npy', allow_pickle=True).item()['RHO']
sa_avg_bsq = np.load('sa_avgbsq.npy', allow_pickle=True).item()['bsq']

sa_avgPgRHO = np.load('sa_avgRHOPg.npy', allow_pickle=True).item()['rhoPg']
sa_avgPgbsq = 2*mu*np.load('sa_avgPgPmag.npy', allow_pickle=True).item()['PgPmag']
sa_avgRHObsq = 2*mu*np.load('sa_avgRHOPmag.npy', allow_pickle=True).item()['rhoPmag']

# covariances
sa_covPgRHO = sa_avgPgRHO - sa_avg_Pg * sa_avg_RHO
sa_covPgbsq = sa_avgPgbsq - sa_avg_Pg * sa_avg_bsq
sa_covRHObsq = sa_avgRHObsq - sa_avg_RHO * sa_avg_bsq

# %%
# coefficients
sa_CPg1 = np.load('sa_CPg1.npy')
sa_Crho1 = np.load('sa_Crho1.npy')
sa_Cbsq1 = np.load('sa_Cbsq1.npy')

# %% [markdown]
# **log(variance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_sa[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_sa[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_sa[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (SANE, Rh=1)')
plt.show()

# %%
r = 32
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_sa[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_sa[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_sa[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (SANE, Rh=1)')
plt.show()

# %%
r = 64
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_sa[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_sa[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_sa[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (SANE, Rh=1)')
plt.show()

# %%
r = 96
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_sa[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_sa[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_sa[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (SANE, Rh=1)')
plt.show()

# %% [markdown]
# Hard to find high resemblance between the variance terms in inner radius (r < 50); starting from the middle-range radius, there's some resemblance between var(Pg), var(RHO) and var(Te)

# %% [markdown]
# **log(covariance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (SANE, Rh=1)')
plt.show()
# Out:
# /tmp/ipykernel_68380/1669968732.py:9: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
# /tmp/ipykernel_68380/1669968732.py:10: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
# /tmp/ipykernel_68380/1669968732.py:11: RuntimeWarning: invalid value encountered in log10
#   axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

# %%
r = 36
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (SANE, Rh=1)')
plt.show()
# Out:
# /tmp/ipykernel_41973/3038151692.py:8: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
# /tmp/ipykernel_41973/3038151692.py:9: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
# /tmp/ipykernel_41973/3038151692.py:10: RuntimeWarning: invalid value encountered in log10
#   axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

# %% [markdown]
# **coefficients VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, sa_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, sa_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, sa_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (SANE, Rh=1)')
plt.show()

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, sa_CPg1[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, sa_Crho1[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, sa_Cbsq1[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (SANE, Rh=1)')
plt.show()

# %% [markdown]
# As r increases:<br>
# C[Pg->Te]: $10^{15}$->$10^{18}$, fewer peaks/troughs <br>
# C[$\rho$->Te]: $-10^{15}$->$-10^{16}$, fewer peaks/troughs <br>
# C[bsq->Te]: $10^{11}$->$10^{12}$, fewer peaks/troughs

# %% [markdown]
# **variances and covariances [Te(calculated) and other quantities] VS $\theta$ with contributions shown**

# %% [markdown]
# var(Te) = $(\delta Te)^{2}$ = $A^{2}$var(Pg) + $B^{2}$var($\rho$) + $C^{2}$var(bsq) + 2$AB$cov(Pg, $\rho$) + 2$AC$ cov(Pg, bsq) + 2$BC$ cov($\rho$, bsq)

# %%
# var(Te) caculated from coefficients and variances
varPg_term = np.square(sa_CPg1)*varPg_sa
varRHO_term = np.square(sa_Crho1)*varRHO_sa
varbsq_term = np.square(sa_Cbsq1)*varbsq_sa
cov_term1 = 2*sa_CPg1*sa_Crho1*sa_covPgRHO
cov_term2 = 2*sa_CPg1*sa_Cbsq1*sa_covPgbsq
cov_term3 = 2*sa_Crho1*sa_Cbsq1*sa_covRHObsq
varTe_coeff = varPg_term + varRHO_term + varbsq_term + cov_term1 + cov_term2 + cov_term3

# %%
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.title('Contribution to var(Te) By Term (SANE, Rh=1)')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.show()

# %%
r = 108
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)
plt.fill_between(theta, np.log10(varTe_sa[r, 0, :]), label='var(Te)[expected]', color='orange', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (SANE, Rh=1)')
plt.ylim(20, 23)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()

# %% [markdown]
# For SANE model, the Pg and $\rho$ terms (**var(Pg), var($\rho$), and cov(Pg, $\rho$)**) are the ones that contribute the most to var(Te), too <br> Some minor fluctuations (more underestimations) at some peaks <br> The smaller r is, the closer the three quantities shown above are

# %% [markdown]
# <h5>Rh=160</h5>

# %%
# the var(Te) expected
varTe_sa_rh160 = np.load('sa_rh160_varTe.npy', allow_pickle=True)

# %%
# coefficients
sa_CPg160 = np.load('sa_CPg160.npy')
sa_Crho160 = np.load('sa_Crho160.npy')
sa_Cbsq160 = np.load('sa_Cbsq160.npy')

# %% [markdown]
# **log(variance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(varPg_sa[r, 0, :]), label='var(Pg) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(varRHO_sa[r, 0, :]), label='var(RHO) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(varbsq_sa[r, 0, :]), label='var(bsq) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(variances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(variances)')
axes[2].legend()

fig.suptitle('Variance Trends Along Theta (SANE, Rh=160)')
plt.show()

# %% [markdown]
# **log(covariance) + log(Te) VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi = 0
axes[0].plot(theta, np.log10(varTe_sa_rh160[r, 0, :]), label='expected var(Te) (at r=%r)'%r)
axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

axes[0].set_xlabel('theta')
axes[0].set_ylabel('log10(varTe)')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].set_ylabel('log10(covariances)')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].set_ylabel('log10(covariances)')
axes[2].legend()
fig.suptitle('Covariance Trends Along Theta (SANE, Rh=160)')
plt.show()
# Out:
# /tmp/ipykernel_82308/2601351513.py:9: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covPgbsq[r, 0, :]), label='cov(Pg, bsq) (at r=%r)'%r, color='green')
# /tmp/ipykernel_82308/2601351513.py:10: RuntimeWarning: invalid value encountered in log10
#   axes[1].plot(theta, np.log10(sa_covRHObsq[r, 0, :]), label='cov(RHO, bsq) (at r=%r)'%r, color='orange')
# /tmp/ipykernel_82308/2601351513.py:11: RuntimeWarning: invalid value encountered in log10
#   axes[2].plot(theta, np.log10(sa_covPgRHO[r, 0, :]), label='cov(Pg, RHO) (at r=%r)'%r, color='purple')

# %% [markdown]
# **coefficients VS $\theta$**

# %%
# choose a radius that represents the spherical surface
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, sa_CPg160[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, sa_Crho160[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, sa_Cbsq160[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (SANE, Rh=1)')
plt.show()

# %%
r = 120
# x axis: theta
theta = np.linspace(0, np.pi, 128)
fig, axes = plt.subplots(1,3, figsize=(15, 4))
# assume phi=0
axes[0].plot(theta, sa_CPg160[r, 0, :], label='C[Pg -> Te] (at r=%r)'%r)
axes[1].plot(theta, sa_Crho160[r, 0, :], label='C[RHO -> Te] (at r=%r)'%r)
axes[2].plot(theta, sa_Cbsq160[r, 0, :], label='C[bsq -> Te] (at r=%r)'%r)

axes[0].set_xlabel('theta')
axes[0].set_ylabel('coefficients')
axes[0].legend()
axes[1].set_xlabel('theta')
axes[1].legend()
axes[2].set_xlabel('theta')
axes[2].legend()
fig.suptitle('Coefficients VS theta (SANE, Rh=1)')
plt.show()

# %% [markdown]
# As r increases: <br>
# C[Pg->Te]: $10^{15}$->$10^{18}$, fewer peaks, less dense <br>
# C[$\rho$->Te]: $-10^{15}$->$-10^{16}$, fewer peaks, less dense <br>
# C[bsq->Te]: $10^{11}$->$10^{12}$, fewer peaks, less dense

# %% [markdown]
# **variances and covariances [Te(calculated) and other quantities] VS $\theta$ with contributions shown**

# %% [markdown]
# var(Te) = $(\delta Te)^{2}$ = $A^{2}$var(Pg) + $B^{2}$var($\rho$) + $C^{2}$var(bsq) + 2$AB$cov(Pg, $\rho$) + 2$AC$ cov(Pg, bsq) + 2$BC$ cov($\rho$, bsq)

# %%
# var(Te) caculated from coefficients and variances
varPg_term = np.square(sa_CPg160)*varPg_sa
varRHO_term = np.square(sa_Crho160)*varRHO_sa
varbsq_term = np.square(sa_Cbsq160)*varbsq_sa
cov_term1 = 2*sa_CPg160*sa_Crho160*sa_covPgRHO
cov_term2 = 2*sa_CPg160*sa_Cbsq160*sa_covPgbsq
cov_term3 = 2*sa_Crho160*sa_Cbsq160*sa_covRHObsq
varTe_coeff = varPg_term + varRHO_term + varbsq_term + cov_term1 + cov_term2 + cov_term3

# %%
r = 5
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, varPg_term[r, 0, :], label='A^2 var(Pg)')
plt.plot(theta, varRHO_term[r, 0, :], label='B^2 var(RHO)')
plt.plot(theta, varbsq_term[r, 0, :], label='C^2 var(bsq)')
plt.plot(theta, cov_term1[r, 0, :], label='AB cov(Pg, RHO)')
plt.plot(theta, cov_term2[r, 0, :], label='AC cov(Pg, bsq)')
plt.plot(theta, cov_term3[r, 0, :], label='BC cov(RHO, bsq)')

plt.fill_between(theta, varTe_coeff[r, 0, :], label='var(Te)[calculated]', color='grey', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('var')
plt.title('Contribution to var(Te) By Term (SANE, Rh=160)')
plt.legend(bbox_to_anchor=(1.5, 1.0))
plt.show()

# %%
r = 88
# x axis: theta
theta = np.linspace(0, np.pi, 128)

plt.plot(theta, np.log10(varPg_term[r, 0, :] + varRHO_term[r, 0, :] + cov_term1[r, 0, :]), label='A^2 var(Pg) + B^2 var(RHO) + AB cov(Pg, RHO)')

plt.fill_between(theta, np.log10(varTe_coeff[r, 0, :]), label='var(Te)[calculated]', color='grey', alpha=0.6)
plt.fill_between(theta, np.log10(varTe_sa_rh160[r, 0, :]), label='var(Te)[expected]', color='orange', alpha=0.6)

plt.xlabel('theta')
plt.ylabel('log(var)')
plt.title('Contribution to var(Te) By Term (SANE, Rh=160)')
plt.ylim(20, 23)
plt.legend(bbox_to_anchor=(2.0, 1.0))
plt.show()
